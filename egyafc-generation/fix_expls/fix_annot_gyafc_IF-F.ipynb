# %%
import pandas as pd
import os
import openai
from time import sleep
from tenacity import (
    retry,
    stop_after_attempt,
    wait_random_exponential,
)  # for exponential backoff

openai.api_key = ''

# %% [markdown]
# # Retreive the prompt and create some functions

# %%
with open("prompt.txt", "r") as f:
    prompt = f.read()

# %%
def make_example(sample):
    return f"\nInformal Sentence: {sample['sent1']}\nInformal Attributes: {sample['expl1']}"

# %%
@retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(6))
def fix_sample(sample):
    messages = [{"role": "user", "content": prompt+make_example(sample)}]
    # print("Informal Sentence:", sample['sent1'])
    # print("Informal Attributes:", sample['expl1'])

    response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=messages,
    temperature=0.1
    )

    resp = response['choices'][0]['message']['content']
    tokens1 = response['usage']['total_tokens']
    # print(resp)

    followup_prompt = """For each attribute in Attributes Listed Incorrectly, remove it from the list of Informal Attributes. Output improved list of Informal Attributes followed by "Improved List:"."""
    # print(followup_prompt)

    followup = [{"role": "assistant", "content": resp},
                {"role": "user", "content": followup_prompt}]
    # print(followup)
    new_messages = messages+followup
    # print(new_messages)

    response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=new_messages,
    temperature=0.1
    )
    tokens2 = response['usage']['total_tokens']

    resp2 = response['choices'][0]['message']['content'].strip()
    # print(resp2)
    # print("/"*20)
    return resp, resp2, tokens1+tokens2

# %% [markdown]
# ## Run on 10K data

# %%
input_directory = "../data/gyafc_expls"
output_directory = "../data/gyafc_fixed_w_HF"

# List all CSV files in the input directory
csv_files = [f for f in os.listdir(input_directory) if f.endswith('.csv')]

# Read the CSV data and combine it from all files
data_frames = []
for csv_file in csv_files:
    data_frames.append(pd.read_csv(os.path.join(input_directory, csv_file)))

# Concatenate all data frames
csv_data_10k = pd.concat(data_frames, ignore_index=True)

# Remove duplicates and rows with missing values
csv_data_10k.drop_duplicates(subset=["informal"], inplace=True)
csv_data_10k.dropna(inplace=True)

#select random 10k examples
csv_data_10k = csv_data_10k.sample(10000, random_state=101).reset_index(drop=True)
# keep only columns biased, neutral_gen, biased_attributes, neutral_attributes
csv_data_10k = csv_data_10k[["informal", "formal_description", "informal_attributes", "formal_attributes"]]
# rename the columns to sent1, sent2, expl1, expl2
csv_data_10k.columns = ["sent1", "sent2", "expl1", "expl2"]
# save the file to output dir
csv_data_10k.to_csv(output_directory + '/gyafc_expls_fixed_w_HF/og_10k.csv', index=False)
print("Saved to", output_directory + '/gyafc_expls_fixed_w_HF/og_10k.csv')

sample = csv_data_10k.iloc[4]
print("Informal Sentence:", sample['sent1'])
print("Informal Attributes:", sample['expl1'])
# Out:
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/og_10k.csv
# Informal Sentence: if u are ready enough to cary responsibility for family you build with your love one.
# Informal Attributes: textese ("u"), contraction ("cary"), colloquialism ("love one"), lack of subject-verb agreement ("you are ready enough")

# %%
total_cost = 0
for batch in range(3500, 10000, 100):
    data = []
    cost = 0
    for idx, sample in csv_data_10k.iloc[batch:batch+100].iterrows():
        r1, r2, tokens = fix_sample(sample)
        cost += tokens
        new_row = [sample['sent1'], sample['sent2'], sample['expl1'], sample['expl2'], r1, r2]
        data.append(new_row)
    total_cost += cost
    print(f"Cost for batch {batch}:", (cost/1000)*0.002)
    print("Total Cost so far:", (total_cost/1000)*0.002)
    df = pd.DataFrame(data, columns=['sent1', 'sent2', 'expl1', 'expl2', 'fixed_expl1', 'fixed_expl2'])
    df['fixed_expl1_list'] = df['fixed_expl2'].apply(lambda x: x.split("Improved List:")[1].strip() if len(x.split("Improved List:")) > 1 else x)
    print("Num of fixed examples:", (df[df['fixed_expl1_list'] != df['expl1']]).shape[0])
    df.to_csv(output_directory + '/gyafc_expls_fixed_w_HF/og_10k_fixed_w_HF_{}.csv'.format(batch), index=False)
    print("Saved to", output_directory + '/gyafc_expls_fixed_w_HF/10k_fixed_batch_{}.csv'.format(batch))
    print("*"*20)
    # break
# Out:
# Cost for batch 3500: 0.5858099999999999
# Total Cost so far: 0.5858099999999999
# Num of fixed examples: 34
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_3500.csv
# ********************
# Cost for batch 3600: 0.5839679999999999
# Total Cost so far: 1.169778
# Num of fixed examples: 22
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_3600.csv
# ********************
# Cost for batch 3700: 0.58587
# Total Cost so far: 1.7556479999999999
# Num of fixed examples: 40
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_3700.csv
# ********************
# Cost for batch 3800: 0.5873039999999999
# Total Cost so far: 2.3429520000000004
# Num of fixed examples: 32
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_3800.csv
# ********************
# Cost for batch 3900: 0.585178
# Total Cost so far: 2.9281300000000003
# Num of fixed examples: 23
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_3900.csv
# ********************
# Cost for batch 4000: 0.586486
# Total Cost so far: 3.514616
# Num of fixed examples: 34
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_4000.csv
# ********************
# Cost for batch 4100: 0.584212
# Total Cost so far: 4.098828
# Num of fixed examples: 22
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_4100.csv
# ********************
# Cost for batch 4200: 0.585678
# Total Cost so far: 4.684506000000001
# Num of fixed examples: 27
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_4200.csv
# ********************
# Cost for batch 4300: 0.589606
# Total Cost so far: 5.274112000000001
# Num of fixed examples: 37
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_4300.csv
# ********************
# Cost for batch 4400: 0.586082
# Total Cost so far: 5.860194000000001
# Num of fixed examples: 31
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_4400.csv
# ********************
# Cost for batch 4500: 0.586116
# Total Cost so far: 6.44631
# Num of fixed examples: 32
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_4500.csv
# ********************
# Cost for batch 4600: 0.586132
# Total Cost so far: 7.0324420000000005
# Num of fixed examples: 37
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_4600.csv
# ********************
# Cost for batch 4700: 0.584212
# Total Cost so far: 7.6166540000000005
# Num of fixed examples: 17
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_4700.csv
# ********************
# Cost for batch 4800: 0.585934
# Total Cost so far: 8.202588
# Num of fixed examples: 30
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_4800.csv
# ********************
# Cost for batch 4900: 0.585132
# Total Cost so far: 8.78772
# Num of fixed examples: 30
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_4900.csv
# ********************
# Cost for batch 5000: 0.585536
# Total Cost so far: 9.373256
# Num of fixed examples: 26
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_5000.csv
# ********************
# Cost for batch 5100: 0.586192
# Total Cost so far: 9.959448
# Num of fixed examples: 35
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_5100.csv
# ********************
# Cost for batch 5200: 0.58588
# Total Cost so far: 10.545328
# Num of fixed examples: 30
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_5200.csv
# ********************
# Cost for batch 5300: 0.58584
# Total Cost so far: 11.131168
# Num of fixed examples: 26
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_5300.csv
# ********************
# Cost for batch 5400: 0.5857859999999999
# Total Cost so far: 11.716954
# Num of fixed examples: 22
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_5400.csv
# ********************
# Cost for batch 5500: 0.586174
# Total Cost so far: 12.303128000000001
# Num of fixed examples: 34
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_5500.csv
# ********************
# Cost for batch 5600: 0.5873060000000001
# Total Cost so far: 12.890433999999999
# Num of fixed examples: 25
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_5600.csv
# ********************
# Cost for batch 5700: 0.5840700000000001
# Total Cost so far: 13.474504000000001
# Num of fixed examples: 28
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_5700.csv
# ********************
# Cost for batch 5800: 0.5853740000000001
# Total Cost so far: 14.059878000000001
# Num of fixed examples: 23
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_5800.csv
# ********************
# Cost for batch 5900: 0.586476
# Total Cost so far: 14.646354
# Num of fixed examples: 30
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_5900.csv
# ********************
# Cost for batch 6000: 0.5856979999999999
# Total Cost so far: 15.232052
# Num of fixed examples: 25
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_6000.csv
# ********************
# Cost for batch 6100: 0.586114
# Total Cost so far: 15.818166
# Num of fixed examples: 34
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_6100.csv
# ********************
# Cost for batch 6200: 0.586616
# Total Cost so far: 16.404782
# Num of fixed examples: 36
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_6200.csv
# ********************
# Cost for batch 6300: 0.586414
# Total Cost so far: 16.991196
# Num of fixed examples: 29
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_6300.csv
# ********************
# Cost for batch 6400: 0.585382
# Total Cost so far: 17.576578
# Num of fixed examples: 23
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_6400.csv
# ********************
# Cost for batch 6500: 0.5857600000000001
# Total Cost so far: 18.162338000000002
# Num of fixed examples: 41
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_6500.csv
# ********************
# Cost for batch 6600: 0.584102
# Total Cost so far: 18.74644
# Num of fixed examples: 18
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_6600.csv
# ********************
# Cost for batch 6700: 0.584962
# Total Cost so far: 19.331401999999997
# Num of fixed examples: 21
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_6700.csv
# ********************
# Cost for batch 6800: 0.586858
# Total Cost so far: 19.91826
# Num of fixed examples: 29
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_6800.csv
# ********************
# Cost for batch 6900: 0.585446
# Total Cost so far: 20.503705999999998
# Num of fixed examples: 31
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_6900.csv
# ********************
# Cost for batch 7000: 0.58609
# Total Cost so far: 21.089796
# Num of fixed examples: 28
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_7000.csv
# ********************
# Cost for batch 7100: 0.584612
# Total Cost so far: 21.674408
# Num of fixed examples: 27
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_7100.csv
# ********************
# Cost for batch 7200: 0.586524
# Total Cost so far: 22.260932
# Num of fixed examples: 30
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_7200.csv
# ********************
# Cost for batch 7300: 0.586302
# Total Cost so far: 22.847234
# Num of fixed examples: 29
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_7300.csv
# ********************
# Cost for batch 7400: 0.585218
# Total Cost so far: 23.432452
# Num of fixed examples: 34
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_7400.csv
# ********************
# Cost for batch 7500: 0.585272
# Total Cost so far: 24.017723999999998
# Num of fixed examples: 33
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_7500.csv
# ********************
# Cost for batch 7600: 0.584198
# Total Cost so far: 24.601922
# Num of fixed examples: 26
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_7600.csv
# ********************
# Cost for batch 7700: 0.5855800000000001
# Total Cost so far: 25.187502000000002
# Num of fixed examples: 31
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_7700.csv
# ********************
# Cost for batch 7800: 0.5875
# Total Cost so far: 25.775002
# Num of fixed examples: 34
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_7800.csv
# ********************
# Cost for batch 7900: 0.585922
# Total Cost so far: 26.360924
# Num of fixed examples: 27
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_7900.csv
# ********************
# Cost for batch 8000: 0.5849059999999999
# Total Cost so far: 26.94583
# Num of fixed examples: 32
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_8000.csv
# ********************
# Cost for batch 8100: 0.5857559999999999
# Total Cost so far: 27.531586
# Num of fixed examples: 24
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_8100.csv
# ********************
# Cost for batch 8200: 0.5853339999999999
# Total Cost so far: 28.11692
# Num of fixed examples: 29
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_8200.csv
# ********************
# Cost for batch 8300: 0.5854020000000001
# Total Cost so far: 28.702322000000002
# Num of fixed examples: 28
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_8300.csv
# ********************
# Cost for batch 8400: 0.5878099999999999
# Total Cost so far: 29.290132000000003
# Num of fixed examples: 35
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_8400.csv
# ********************
# Cost for batch 8500: 0.58588
# Total Cost so far: 29.876012
# Num of fixed examples: 28
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_8500.csv
# ********************
# Cost for batch 8600: 0.588586
# Total Cost so far: 30.464598000000002
# Num of fixed examples: 29
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_8600.csv
# ********************
# Cost for batch 8700: 0.582918
# Total Cost so far: 31.047516
# Num of fixed examples: 26
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_8700.csv
# ********************
# Cost for batch 8800: 0.5899099999999999
# Total Cost so far: 31.637426
# Num of fixed examples: 38
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_8800.csv
# ********************
# Cost for batch 8900: 0.587682
# Total Cost so far: 32.225108
# Num of fixed examples: 34
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_8900.csv
# ********************
# Cost for batch 9000: 0.586246
# Total Cost so far: 32.811354
# Num of fixed examples: 28
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_9000.csv
# ********************
# Cost for batch 9100: 0.5858540000000001
# Total Cost so far: 33.397208
# Num of fixed examples: 25
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_9100.csv
# ********************
# Cost for batch 9200: 0.58492
# Total Cost so far: 33.982127999999996
# Num of fixed examples: 28
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_9200.csv
# ********************
# Cost for batch 9300: 0.585062
# Total Cost so far: 34.567190000000004
# Num of fixed examples: 28
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_9300.csv
# ********************
# Cost for batch 9400: 0.585904
# Total Cost so far: 35.153093999999996
# Num of fixed examples: 25
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_9400.csv
# ********************
# Cost for batch 9500: 0.586802
# Total Cost so far: 35.739896
# Num of fixed examples: 29
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_9500.csv
# ********************
# Cost for batch 9600: 0.585032
# Total Cost so far: 36.324928
# Num of fixed examples: 24
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_9600.csv
# ********************
# Cost for batch 9700: 0.585346
# Total Cost so far: 36.910274
# Num of fixed examples: 31
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_9700.csv
# ********************
# Cost for batch 9800: 0.5895119999999999
# Total Cost so far: 37.499786
# Num of fixed examples: 29
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_9800.csv
# ********************
# Cost for batch 9900: 0.5857340000000001
# Total Cost so far: 38.085519999999995
# Num of fixed examples: 32
# Saved to ../data/gyafc_fixed_w_HF/gyafc_expls_fixed_w_HF/10k_fixed_batch_9900.csv
# ********************
