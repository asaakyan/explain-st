# %%
import torch
import os
import json

# %%
os.environ['HF_HOME'] =  "/mnt/swordfish-pool2/models/"
# os.environ["CUDA_VISIBLE_DEVICES"]="2,3"
from transformers import AutoTokenizer, AutoModelForCausalLM, GenerationConfig

# %% [markdown]
# # Tulu-65B

# %%
# dir_of_hf_w = "/mnt/swordfish-pool2/models/vicuna/13B"
dir_of_hf_w = "/mnt/swordfish-pool2/models/tulu"
print("Loading the model and tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(dir_of_hf_w)
model = AutoModelForCausalLM.from_pretrained(
    dir_of_hf_w,
    load_in_8bit=True,
    device_map="auto",
)
model.eval()
# Out:
# Loading the model and tokenizer...
# Overriding torch_dtype=None with `torch_dtype=torch.float16` due to requirements of `bitsandbytes` to enable model loading in mixed int8. Either pass torch_dtype=torch.float16 or don't pass this argument at all to remove this warning.
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please run
#
# python -m bitsandbytes
#
#  and submit this information together with your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# bin /home/a.saakyan/tmp/ENTER/envs/alpaca/lib/python3.10/site-packages/bitsandbytes/libbitsandbytes_cuda118.so
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so.11.0
# CUDA SETUP: Highest compute capability among GPUs detected: 8.0
# CUDA SETUP: Detected CUDA version 118
# CUDA SETUP: Loading binary /home/a.saakyan/tmp/ENTER/envs/alpaca/lib/python3.10/site-packages/bitsandbytes/libbitsandbytes_cuda118.so...
# /home/a.saakyan/tmp/ENTER/envs/alpaca/lib/python3.10/site-packages/bitsandbytes/cuda_setup/main.py:145: UserWarning: /home/a.saakyan/tmp/ENTER/envs/alpaca did not contain ['libcudart.so', 'libcudart.so.11.0', 'libcudart.so.12.0'] as expected! Searching further paths...
#   warn(msg)
# Loading checkpoint shards:   0%|          | 0/27 [00:00<?, ?it/s]
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(32001, 8192, padding_idx=0)
#     (layers): ModuleList(
#       (0-79): 80 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear8bitLt(in_features=8192, out_features=8192, bias=False)
#           (k_proj): Linear8bitLt(in_features=8192, out_features=8192, bias=False)
#           (v_proj): Linear8bitLt(in_features=8192, out_features=8192, bias=False)
#           (o_proj): Linear8bitLt(in_features=8192, out_features=8192, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear8bitLt(in_features=8192, out_features=22016, bias=False)
#           (down_proj): Linear8bitLt(in_features=22016, out_features=8192, bias=False)
#           (up_proj): Linear8bitLt(in_features=8192, out_features=22016, bias=False)
#           (act_fn): SiLUActivation()
#         )
#         (input_layernorm): LlamaRMSNorm()
#         (post_attention_layernorm): LlamaRMSNorm()
#       )
#     )
#     (norm): LlamaRMSNorm()
#   )
#   (lm_head): Linear(in_features=8192, out_features=32001, bias=False)
# )

# %%
def evaluate(tokenizer, model, 
             input, instruction=None, fs_prompt=None, 
             verbose=False):
    prompt = generate_prompt(input, instruction, fs_prompt)
    if verbose: 
        print("****PROMPT:****")
        print(prompt)
        print("****END PROMPT****")
    inputs = tokenizer(prompt, return_tensors="pt")
    input_ids = inputs["input_ids"].cuda() # these are integers encoded from words
    generation_config = GenerationConfig(
        do_sample=True,
        temperature=0.7,
        top_p=0.9,
        seed=42,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id
    )
    generation_output = model.generate(
        input_ids=input_ids,
        generation_config=generation_config,
        return_dict_in_generate=True,
        output_scores=True,
        max_new_tokens=256,
    )
    s = generation_output.sequences[0]
    output = tokenizer.decode(s)
    # return output.split("### Response:")[1].replace("</s>", "").strip()
    # return output.strip().replace("</s>", "").replace("<s>", "")
    return output.split("<assistant>")[1].replace("</s>", "").strip()


def construct_few_shot_prompt(train_file_path, n=10):
    # prompt = "Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request."
    # sample 10 instances from train.json
    with open(train_file_path, "r") as f:
        train_samples = json.load(f)
        train_samples = train_samples[:n]
    for i, row in enumerate(train_samples):
        instruction, input, response = row["instruction"], row["input"], row["output"]
        if i ==0: prompt = f"""<user>\n{instruction}\nFor example:\n"""
        prompt += f"""{input}
{response}

"""
    prompt = f"{prompt}For the following sentence, {instruction.lower()}"
    return prompt.strip()

def generate_prompt(input, instruction=None, fs_prompt=None):
    if input and instruction:
        return f"""{instruction}
        
{input}\n<assistant>\n"""
    if input and fs_prompt:
        return f"""{fs_prompt}
        
{input}\n<assistant>\n"""

def run_inference(input_json, out_dir,
                   model_name, model, tokenizer,
                   n_shots = True, train_file_path=None,
                   verbose=False, 
                   start_idx = 1, stop_idx=10000):
    
    output = []
    with open( input_json,'r') as fp:
        test_file = json.load(fp)
        
    for i, line in enumerate(test_file):
        if i < start_idx: continue
        if i > stop_idx: break

        print(f"INSTANCE {i}, percentage: {i/len(test_file)}")
        if verbose: print(f"INSTRUCTION: {line['instruction']}\nINPUT: {line['input']}\n")

        if n_shots == 0:
            pred = evaluate(tokenizer, model, 
                            input=line['input'], instruction=line['instruction'], 
                            verbose=verbose)
        else:
            fs_prompt = construct_few_shot_prompt(train_file_path, n=n_shots)
            pred = evaluate(tokenizer, model, 
                            input=line['input'], fs_prompt=fs_prompt,
                            verbose=verbose)
            
        output += [{"instruction": line['instruction'],
                "input": line['input'],
                "pred": pred,
                "id": i
                }]
        if verbose:
            print("RESPONSE:\n", pred)
            print("-"*50)

        if i%10==0:
            with open(f"{out_dir}/{model_name}_test_output_{start_idx}_{stop_idx}.json",'w', encoding='utf-8') as fp:
                json.dump(output, fp, indent=4)
    # final save
    with open(f"{out_dir}/{model_name}_test_output_{start_idx}_{stop_idx}.json",'w', encoding='utf-8') as fp:
            json.dump(output, fp, indent=4)
    return output

# %%
out_dir = "../..//data/gyafc_w_ICHF_alpaca/informal_to_formal"
assert os.path.isdir(out_dir)
input_json = "../../data/gyafc_w_ICHF_alpaca/informal_to_formal/test.json"
assert os.path.isfile(input_json)
train_file_path = "../../data/gyafc_w_ICHF_alpaca/informal_to_formal/train.json"
assert os.path.isfile(train_file_path)

# fs_prompt = construct_few_shot_prompt(train_file_path, n=3)
# print(generate_prompt(input="test", fs_prompt=fs_prompt))

run_inference(input_json, out_dir, 
              "tulu", model, tokenizer, 
              n_shots=1, train_file_path=train_file_path,
              verbose=False, start_idx=800, stop_idx=2000)
# Out:
# INSTANCE 800, percentage: 0.40816326530612246
# INSTANCE 801, percentage: 0.4086734693877551
# INSTANCE 802, percentage: 0.4091836734693878
# INSTANCE 803, percentage: 0.40969387755102044
# INSTANCE 804, percentage: 0.41020408163265304
# INSTANCE 805, percentage: 0.4107142857142857
# INSTANCE 806, percentage: 0.41122448979591836
# INSTANCE 807, percentage: 0.411734693877551
# INSTANCE 808, percentage: 0.4122448979591837
# INSTANCE 809, percentage: 0.41275510204081634
# INSTANCE 810, percentage: 0.413265306122449
# INSTANCE 811, percentage: 0.41377551020408165
# INSTANCE 812, percentage: 0.4142857142857143
# INSTANCE 813, percentage: 0.4147959183673469
# INSTANCE 814, percentage: 0.4153061224489796
# INSTANCE 815, percentage: 0.41581632653061223
# INSTANCE 816, percentage: 0.4163265306122449
# INSTANCE 817, percentage: 0.41683673469387755
# INSTANCE 818, percentage: 0.4173469387755102
# INSTANCE 819, percentage: 0.41785714285714287
# INSTANCE 820, percentage: 0.41836734693877553
# INSTANCE 821, percentage: 0.4188775510204082
# INSTANCE 822, percentage: 0.4193877551020408
# INSTANCE 823, percentage: 0.41989795918367345
# INSTANCE 824, percentage: 0.4204081632653061
# INSTANCE 1825, percentage: 0.9311224489795918
# INSTANCE 1826, percentage: 0.9316326530612244
# INSTANCE 1827, percentage: 0.9321428571428572
# INSTANCE 1828, percentage: 0.9326530612244898
# INSTANCE 1829, percentage: 0.9331632653061225
# INSTANCE 1830, percentage: 0.9336734693877551
# INSTANCE 1831, percentage: 0.9341836734693878
# INSTANCE 1832, percentage: 0.9346938775510204
# INSTANCE 1833, percentage: 0.935204081632653
# INSTANCE 1834, percentage: 0.9357142857142857
# INSTANCE 1835, percentage: 0.9362244897959183
# INSTANCE 1836, percentage: 0.936734693877551
# INSTANCE 1837, percentage: 0.9372448979591836
# INSTANCE 1838, percentage: 0.9377551020408164
# INSTANCE 1839, percentage: 0.938265306122449
# INSTANCE 1840, percentage: 0.9387755102040817
# INSTANCE 1841, percentage: 0.9392857142857143
# INSTANCE 1842, percentage: 0.939795918367347
# INSTANCE 1843, percentage: 0.9403061224489796
# INSTANCE 1844, percentage: 0.9408163265306122
# INSTANCE 1845, percentage: 0.9413265306122449
# INSTANCE 1846, percentage: 0.9418367346938775
# INSTANCE 1847, percentage: 0.9423469387755102
# INSTANCE 1848, percentage: 0.9428571428571428
# INSTANCE 1849, percentage: 0.9433673469387756
# INSTANCE 1850, percentage: 0.9438775510204082
# INSTANCE 1851, percentage: 0.9443877551020409
# INSTANCE 1852, percentage: 0.9448979591836735
# INSTANCE 1853, percentage: 0.9454081632653061
# ...
#   'id': 1764},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': "Informal: If you're up for the adventure!",
#   'pred': 'Informal Attributes: exclamation mark (!), informal language ("up for the adventure")',
#   'id': 1765},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: just shout if i cn help with anythn.',
#   'pred': 'Informal Attributes: contraction ("cn"), informal language ("shout")',
#   'id': 1766},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': "Informal: I don't, why watch it when you can have the real deal?",
#   'pred': 'Informal Attributes: informal language ("don\'t"), contraction ("why watch it")',
#   'id': 1767},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: Maybe she thinks u r some kind a virus or 3.',
#   'pred': 'Informal Attributes: informal language ("Maybe she thinks u r some kind a virus or 3."), texting abbreviations ("u" for "you")',
#   'id': 1768},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': "Informal: the short version: don't do it.",
#   'pred': 'Informal Attributes: contraction ("don\'t"), informal language ("version")\nFormal: The abridged version: it is not advisable.\nFormal Attributes: absence of contraction, sophisticated language ("abridged", "advisable")',
#   'id': 1769},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': "Informal: if you aren't happy move on.",
#   'pred': 'Informal Attributes: imperative sentence form ("move on"), informal language ("aren\'t", "happy")',
#   'id': 1770},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: u have to find a real love than never care about being tall or not ....',
#   'pred': 'Informal Attributes: contraction ("u"), informal language ("real love"), colloquial expression ("never care about being tall or not")\nFormal: You must discover a genuine affection that does not concern itself with height or the lack thereof.\\Formal Attributes: standard written form ("you must"), lexical sophistication ("genuine affection"), absence of colloquial expressions',
#   'id': 1771},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': "Informal: Oh girl.. don't get me started.",
#   'pred': 'Informal Attributes: direct statement form ("don\'t get me started"), informal language ("girl")',
#   'id': 1772},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: uhhhhh.. Im gonna have to say yyyeah.. Just being honest.',
#   'pred': 'Informal Attributes: informal language ("uhhhhh"), contractions ("Im", "yyyeah"), colloquialisms ("just being honest")',
#   'id': 1773},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: well it depends where you want the meat.',
#   'pred': 'Informal Attributes: informal language ("well"), use of contraction ("it\'s"), lack of specificity ("want the meat")\nFormal: Would you like the meat to be located in a specific area?\\Formal Attributes: indirect question form ("would you like"), use of specific terminology ("located"), clear and specific language ("specific area")',
#   'id': 1774},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: do u mean being a straight and gay at the same time?',
#   'pred': 'Informal Attributes: informal language ("do u mean"), contraction ("u"), use of slang ("straight and gay")\nFormal: Do you mean being heterosexual and homosexual simultaneously?\\Formal Attributes: formal language ("Do you mean"), full spelling ("you"), use of technical terms ("heterosexual and homosexual")',
#   'id': 1775},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: arrange to meet him in person and if he comes then u know he likes u',
#   'pred': 'Informal Attributes: direct question form ("arrange to meet him in person"), informal language ("he likes u")\nFormal: What steps could you take to determine if an individual is interested in meeting with you?\\Formal Attributes: indirect question form ("what steps could you take"), lexical sophistication ("individual", "interested in meeting with you")',
#   'id': 1776},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: If you have to start counting on your toes...',
#   'pred': 'Informal Attributes: informal language ("have to start counting"), ellipsis (...)',
#   'id': 1777},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: You damn kids with this boogie jive nonesense, ingnorant as hell!',
#   'pred': 'Informal Attributes: informal language ("damn", "kids", "boogie jive", "ignorant"), colloquial contraction ("y\'all"), exclamation point\nFormal: You, young people, with this boogie jive nonsense, are quite uninformed.',
#   'id': 1778},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: Nothing like big hair, fake nails, and lycra to get a guy going.',
#   'pred': 'Informal Attributes: informal language ("big hair", "fake nails", "get a guy going"), colloquial expression ("nothing like")',
#   'id': 1779},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: good luck trying to pull that off.',
#   'pred': 'Informal Attributes: colloquial language ("good luck"), idiomatic expression ("pull that off")',
#   'id': 1780},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: if a guy calls a girl he already shows interest.',
#   'pred': 'Informal Attributes: informal language ("guy", "girl"), colloquial contraction ("calls a girl" instead of "calls a young woman")',
#   'id': 1781},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: Then you will really be asking quastions here  lol',
#   'pred': 'Informal Attributes: informal language ("here lol"), direct question form ("you will really be asking questions")',
#   'id': 1782},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': "Informal: there's a lot so i'll try to narrow it down to 3 things.",
#   'pred': 'Informal Attributes: contraction ("there\'s"), colloquial language ("i\'ll try to"), casual tone\nFormal: There are numerous points to consider, so I shall attempt to condense them into three main items.\nFormal Attributes: formal language ("There are numerous points to consider"), formal tone, no contractions',
#   'id': 1783},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: Should I tell him that I love him?',
#   'pred': 'Informal Attributes: direct question form ("should I tell him"), informal language ("tell him that I love him")',
#   'id': 1784},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': "Informal: I'm 18 and I want to get marry right now.",
#   'pred': 'Informal Attributes: direct statement form ("I\'m 18"), informal language ("want to get marry"), informal punctuation ("right now")',
#   'id': 1785},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: Should i give him a chance?',
#   'pred': 'Informal Attributes: direct question form ("should i"), informal language ("i", "chance")',
#   'id': 1786},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: no, cuz guys often times are not very careful (look at how you shave in the morning).',
#   'pred': 'Informal Attributes: informal language ("cuz", "times"), use of contractions ("often times"), colloquial expression ("not very careful"), personal example ("look at how you shave in the morning")',
#   'id': 1787},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: he knows he can look but he cant touch.',
#   'pred': 'Informal Attributes: simple sentence structure, informal language ("he knows he can look but he can\'t touch")',
#   'id': 1788},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: I like my neighbor too...but take it slow.',
#   'pred': 'Informal Attributes: informal language ("I like my neighbor too"), colloquial contraction ("but take it slow")',
#   'id': 1789},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: IF YOU ARE INTERESTED IN DOING THIS WHY SHOULD IT MATTER WHAT ANYONE THINKS.',
#   'pred': 'Informal Attributes: upper case letters for emphasis ("IF YOU ARE INTERESTED"), informal language ("it shouldn\'t matter what anyone thinks")',
#   'id': 1790},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: Except, you could start flirting with her.',
#   'pred': 'Informal Attributes: direct statement form ("you could start flirting"), informal language ("except", "flirting")',
#   'id': 1791},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: somehow i agree with them , because the nature gives her the role of feeding and protcting !',
#   'pred': 'Informal Attributes: informal language ("somehow", "i agree"), contraction ("i"), colloquial expression ("nature gives her the role")\nFormal: I must concur with their viewpoint, as it is inherent in her nature to provide sustenance and protection.\nFormal Attributes: formal language ("must concur", "viewpoint"), no contraction ("I"), academic tone ("inherent in her nature")',
#   'id': 1792},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: what does your gut instincts say ??',
#   'pred': 'Informal Attributes: direct question form ("what does"), informal language ("gut instincts")\nFormal: What does your intuition suggest?\\Formal Attributes: indirect question form ("what does your intuition suggest"), lexical sophistication ("intuition")',
#   'id': 1793},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: i guess because he would just come up to me and do it without notice.',
#   'pred': 'Informal Attributes: informal language ("guess", "just come up"), lack of syntactic complexity ("without notice")',
#   'id': 1794},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: who cares about what your friends think.',
#   'pred': 'Informal Attributes: use of the pronoun "who" to refer to a person, informal language ("cares about", "what your friends think")\nFormal: How much consideration should be given to the opinions of one\'s peers?\\Formal Attributes: indirect question form ("how much consideration"), lexical sophistication ("consideration", "opinions")',
#   'id': 1795},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: this guy might want to kiss you but he needs time to find the right moment.',
#   'pred': 'Informal Attributes: direct statement form ("might want"), informal language ("guy", "kiss you"), use of contraction ("might")\nFormal: It is possible that this individual may desire to kiss you, but he requires time to identify the appropriate moment. \\Formal Attributes: indirect statement form ("is possible that"), formal language ("individual", "desire"), use of full word ("may")',
#   'id': 1796},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: If you are with a woman who also likes it, then go ahead!!!!',
#   'pred': 'Informal Attributes: exclamation mark (!), direct statement ("go ahead"), informal language ("woman")',
#   'id': 1797},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: You sound like someone that is desparate for love!',
#   'pred': 'Informal Attributes: direct statement form ("You sound like"), informal language ("desparate", "love")',
#   'id': 1798},
#  {'instruction': 'Identify informal attributes in a given sentence, modify them to create a formal sentence, and then output the attributes of the generated formal sentence.',
#   'input': 'Informal: theres more fighting and killings because religions.',
#   'pred': 'Informal Attributes: direct statement form ("theres more"), informal language ("fighting and killings"), informal grammar ("because religions")',
#   'id': 1799},
#  ...]

# %%
# out_dir = "../data/gyafc_w_ICHF_alpaca/formal_to_informal"
# assert os.path.isdir(out_dir)
# input_json = "../data/gyafc_w_ICHF_alpaca/formal_to_informal/test.json"
# assert os.path.isfile(input_json)
# train_file_path = "../data/gyafc_w_ICHF_alpaca/formal_to_informal/train.json"
# assert os.path.isfile(train_file_path)

# run_inference(input_json, out_dir, 
#               "tulu", model, tokenizer, 
#               n_shots=1, train_file_path=train_file_path,
#               verbose=False, start_idx = 0, stop_idx=400)
